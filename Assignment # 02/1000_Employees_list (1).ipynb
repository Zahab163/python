# %%
employee_1= {"employee_id":1,
            "employee_name":"Sony",
            "employee_salary":100000000,
            "employee_designation":"CEO",
            "employee_skills":["python","AI_engineer", "data_scientist","Management","Digital_Marketing"],
            "employee_experience":[
                {"company_Id":1,
                 "designation": "assistant",
                 "salary":100000,
                 "skills":"python, Javascript " },
                {"company_id":2,
                 "designation": "assistant_manager",
                 "salary" :1000000,
                 "skills":"python, AI_engineer, web_development"}

           ]
           }

# %%
employee_2 = {"employee_id": 2,
           "employee_name": "Shiza",
           "employee_salary": 100000000,
           "employee_designation": "Manager",
           "employee_skills": ["python", "AI_engineer", "data_scientist", "supervision" ] ,
           "employee_experience": [
               {"company_Id": 1,
                "designation": "assistant",
                "salary": 100000,
                "skills": "python, Javascript "},
               {"company_id": 2,
                "designation": "assistant_manager",
                "salary": 1000000,
                "skills": ["python, AI_engineer, web_development"]}

           ]
           }

# %%
# Access the employee_experience list
employee_experience = employee_1["employee_experience"]

# Iterate through each experience entry
for experience in employee_experience:
    # Access the skills for the current experience
    skills_data = experience.get("skills") # Use .get() to handle potential missing key
    if skills_data:
        # If skills is a string, split it and print
        if isinstance(skills_data, str):
            skills_list = [skill.strip() for skill in skills_data.split(',') if skill.strip()]
            print(f"Experience Skills: {', '.join(skills_list)}")
        # If skills is already a list, print its elements
        elif isinstance(skills_data, list):
            print(f"Experience Skills: {', '.join(skills_data)}")
# Out:
# Experience Skills: python, Javascript
# Experience Skills: python, AI_engineer, web_development

# %%
# You can install Faker if you want more realistic data:
# !pip install Faker

from faker import Faker
import random

# Initialize Faker
fake = Faker()

def create_employee(employee_id):
    """Creates a dictionary representing a single employee."""
    return {
        "employee_id": employee_id,
        "employee_name": fake.name(),
        "employee_salary": random.randint(50000, 200000),  # Simulate salary range
        "employee_designation": random.choice(["Manager", "Developer", "Analyst", "Designer"]), # Simulate designation
        "employee_skills": random.sample(["python", "java", "SQL", "machine learning", "data analysis", "communication"], k=random.randint(1, 5)), # Simulate skills
        "employee_experience": [
            {"company_id": fake.random_int(min=1, max=10),
             "designation": fake.job(),
             "salary": random.randint(30000, 150000),
             "skills": ", ".join(random.sample(["python", "java", "SQL", "machine learning", "data analysis", "communication"], k=random.randint(1, 3)))}
        ]
    }

# Create a list of 100 employees
employee_list = [create_employee(i) for i in range(1, 1001)]

# To see the generated list:
# print(employee_list)
# Out:
# Collecting Faker
#   Downloading faker-37.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from Faker) (2025.2)
# Downloading faker-37.3.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.0 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-37.3.0

# %%
print(employee_list)
# Out:
# [{'employee_id': 1, 'employee_name': 'Clayton Turner', 'employee_salary': 88218, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'java', 'machine learning'], 'employee_experience': [{'company_id': 7, 'designation': 'Recycling officer', 'salary': 131234, 'skills': 'data analysis, machine learning'}]}, {'employee_id': 2, 'employee_name': 'Bruce Phillips', 'employee_salary': 194744, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'SQL', 'communication', 'python'], 'employee_experience': [{'company_id': 4, 'designation': 'Clinical biochemist', 'salary': 55537, 'skills': 'communication'}]}, {'employee_id': 3, 'employee_name': 'William Bruce', 'employee_salary': 148092, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'SQL', 'data analysis', 'java'], 'employee_experience': [{'company_id': 3, 'designation': 'Physiotherapist', 'salary': 112103, 'skills': 'SQL, communication'}]}, {'employee_id': 4, 'employee_name': 'Peter Ayala', 'employee_salary': 93758, 'employee_designation': 'Designer', 'employee_skills': ['machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Counsellor', 'salary': 83832, 'skills': 'python'}]}, {'employee_id': 5, 'employee_name': 'Willie Wright', 'employee_salary': 114629, 'employee_designation': 'Developer', 'employee_skills': ['python', 'communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Sales professional, IT', 'salary': 139006, 'skills': 'python, communication'}]}, {'employee_id': 6, 'employee_name': 'Lori Richmond', 'employee_salary': 168309, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'java', 'SQL', 'machine learning', 'python'], 'employee_experience': [{'company_id': 6, 'designation': 'IT consultant', 'salary': 125288, 'skills': 'SQL, machine learning'}]}, {'employee_id': 7, 'employee_name': 'Jennifer Hernandez', 'employee_salary': 111613, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Air cabin crew', 'salary': 148227, 'skills': 'data analysis'}]}, {'employee_id': 8, 'employee_name': 'Jason Terry', 'employee_salary': 166667, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 9, 'designation': 'Petroleum engineer', 'salary': 31013, 'skills': 'python, data analysis, communication'}]}, {'employee_id': 9, 'employee_name': 'Joseph Williams', 'employee_salary': 103784, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'communication', 'python', 'java', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Research scientist (physical sciences)', 'salary': 69261, 'skills': 'machine learning, SQL, java'}]}, {'employee_id': 10, 'employee_name': 'Eric Stone', 'employee_salary': 187942, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Theatre director', 'salary': 107687, 'skills': 'machine learning'}]}, {'employee_id': 11, 'employee_name': 'Sergio Morrison', 'employee_salary': 119705, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Magazine features editor', 'salary': 86019, 'skills': 'java'}]}, {'employee_id': 12, 'employee_name': 'Justin Mccormick', 'employee_salary': 125520, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 8, 'designation': 'Administrator, education', 'salary': 68951, 'skills': 'machine learning, communication'}]}, {'employee_id': 13, 'employee_name': 'Tony Miller', 'employee_salary': 57324, 'employee_designation': 'Developer', 'employee_skills': ['python', 'data analysis', 'machine learn ...

# %%
employee_list[0]
# Out:
# {'employee_id': 1,
#  'employee_name': 'Clayton Turner',
#  'employee_salary': 88218,
#  'employee_designation': 'Manager',
#  'employee_skills': ['data analysis', 'java', 'machine learning'],
#  'employee_experience': [{'company_id': 7,
#    'designation': 'Recycling officer',
#    'salary': 131234,
#    'skills': 'data analysis, machine learning'}]}

# %%
print(employee_list[0:1001])
# Out:
# [{'employee_id': 1, 'employee_name': 'Clayton Turner', 'employee_salary': 88218, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'java', 'machine learning'], 'employee_experience': [{'company_id': 7, 'designation': 'Recycling officer', 'salary': 131234, 'skills': 'data analysis, machine learning'}]}, {'employee_id': 2, 'employee_name': 'Bruce Phillips', 'employee_salary': 194744, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'SQL', 'communication', 'python'], 'employee_experience': [{'company_id': 4, 'designation': 'Clinical biochemist', 'salary': 55537, 'skills': 'communication'}]}, {'employee_id': 3, 'employee_name': 'William Bruce', 'employee_salary': 148092, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'SQL', 'data analysis', 'java'], 'employee_experience': [{'company_id': 3, 'designation': 'Physiotherapist', 'salary': 112103, 'skills': 'SQL, communication'}]}, {'employee_id': 4, 'employee_name': 'Peter Ayala', 'employee_salary': 93758, 'employee_designation': 'Designer', 'employee_skills': ['machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Counsellor', 'salary': 83832, 'skills': 'python'}]}, {'employee_id': 5, 'employee_name': 'Willie Wright', 'employee_salary': 114629, 'employee_designation': 'Developer', 'employee_skills': ['python', 'communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Sales professional, IT', 'salary': 139006, 'skills': 'python, communication'}]}, {'employee_id': 6, 'employee_name': 'Lori Richmond', 'employee_salary': 168309, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'java', 'SQL', 'machine learning', 'python'], 'employee_experience': [{'company_id': 6, 'designation': 'IT consultant', 'salary': 125288, 'skills': 'SQL, machine learning'}]}, {'employee_id': 7, 'employee_name': 'Jennifer Hernandez', 'employee_salary': 111613, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Air cabin crew', 'salary': 148227, 'skills': 'data analysis'}]}, {'employee_id': 8, 'employee_name': 'Jason Terry', 'employee_salary': 166667, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 9, 'designation': 'Petroleum engineer', 'salary': 31013, 'skills': 'python, data analysis, communication'}]}, {'employee_id': 9, 'employee_name': 'Joseph Williams', 'employee_salary': 103784, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'communication', 'python', 'java', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Research scientist (physical sciences)', 'salary': 69261, 'skills': 'machine learning, SQL, java'}]}, {'employee_id': 10, 'employee_name': 'Eric Stone', 'employee_salary': 187942, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Theatre director', 'salary': 107687, 'skills': 'machine learning'}]}, {'employee_id': 11, 'employee_name': 'Sergio Morrison', 'employee_salary': 119705, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Magazine features editor', 'salary': 86019, 'skills': 'java'}]}, {'employee_id': 12, 'employee_name': 'Justin Mccormick', 'employee_salary': 125520, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 8, 'designation': 'Administrator, education', 'salary': 68951, 'skills': 'machine learning, communication'}]}, {'employee_id': 13, 'employee_name': 'Tony Miller', 'employee_salary': 57324, 'employee_designation': 'Developer', 'employee_skills': ['python', 'data analysis', 'machine learn ...

# %%
for employee in employee_list[0:1001]:
 print(employee)
# Out:
# {'employee_id': 1, 'employee_name': 'Clayton Turner', 'employee_salary': 88218, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'java', 'machine learning'], 'employee_experience': [{'company_id': 7, 'designation': 'Recycling officer', 'salary': 131234, 'skills': 'data analysis, machine learning'}]}
# {'employee_id': 2, 'employee_name': 'Bruce Phillips', 'employee_salary': 194744, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'SQL', 'communication', 'python'], 'employee_experience': [{'company_id': 4, 'designation': 'Clinical biochemist', 'salary': 55537, 'skills': 'communication'}]}
# {'employee_id': 3, 'employee_name': 'William Bruce', 'employee_salary': 148092, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'SQL', 'data analysis', 'java'], 'employee_experience': [{'company_id': 3, 'designation': 'Physiotherapist', 'salary': 112103, 'skills': 'SQL, communication'}]}
# {'employee_id': 4, 'employee_name': 'Peter Ayala', 'employee_salary': 93758, 'employee_designation': 'Designer', 'employee_skills': ['machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Counsellor', 'salary': 83832, 'skills': 'python'}]}
# {'employee_id': 5, 'employee_name': 'Willie Wright', 'employee_salary': 114629, 'employee_designation': 'Developer', 'employee_skills': ['python', 'communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Sales professional, IT', 'salary': 139006, 'skills': 'python, communication'}]}
# {'employee_id': 6, 'employee_name': 'Lori Richmond', 'employee_salary': 168309, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'java', 'SQL', 'machine learning', 'python'], 'employee_experience': [{'company_id': 6, 'designation': 'IT consultant', 'salary': 125288, 'skills': 'SQL, machine learning'}]}
# {'employee_id': 7, 'employee_name': 'Jennifer Hernandez', 'employee_salary': 111613, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Air cabin crew', 'salary': 148227, 'skills': 'data analysis'}]}
# {'employee_id': 8, 'employee_name': 'Jason Terry', 'employee_salary': 166667, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 9, 'designation': 'Petroleum engineer', 'salary': 31013, 'skills': 'python, data analysis, communication'}]}
# {'employee_id': 9, 'employee_name': 'Joseph Williams', 'employee_salary': 103784, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'communication', 'python', 'java', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Research scientist (physical sciences)', 'salary': 69261, 'skills': 'machine learning, SQL, java'}]}
# {'employee_id': 10, 'employee_name': 'Eric Stone', 'employee_salary': 187942, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Theatre director', 'salary': 107687, 'skills': 'machine learning'}]}
# {'employee_id': 11, 'employee_name': 'Sergio Morrison', 'employee_salary': 119705, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Magazine features editor', 'salary': 86019, 'skills': 'java'}]}
# {'employee_id': 12, 'employee_name': 'Justin Mccormick', 'employee_salary': 125520, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 8, 'designation': 'Administrator, education', 'salary': 68951, 'skills': 'machine learning, communication'}]}
# {'employee_id': 13, 'employee_name': 'Tony Miller', 'employee_salary': 57324, 'employee_designation': 'Developer', 'employee_skills': ['python', 'data analysis', 'machine learning', 'java', 'communication'], 'employee_experience': [{'company_id': 2, 'designation': 'Music therapist', 'salary': 109118, 'skills': 'SQL, data analysis'}]}
# {'employee_id': 14, 'employee_name': 'Rachel Murillo', 'employee_salary': 54938, 'employee_designation': 'Manager', 'employee_skills': ['python', 'machine learning', 'java', 'SQL', 'data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Government social research officer', 'salary': 94359, 'skills': 'data analysis, communication, java'}]}
# {'employee_id': 15, 'employee_name': 'Angela Mcintosh', 'employee_salary': 60359, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'data analysis', 'SQL', 'java', 'machine learning'], 'employee_experience': [{'company_id': 5, 'designation': 'Arts administrator', 'salary': 144911, 'skills': 'machine learning, python'}]}
# {'employee_id': 16, 'employee_name': 'Nicholas Smith', 'employee_salary': 50597, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 10, 'designation': 'Engineer, aeronautical', 'salary': 57361, 'skills': 'SQL, python'}]}
# {'employee_id': 17, 'employee_name': 'Ashley Reeves', 'employee_salary': 68999, 'employee_designation': 'Designer', 'employee_skills': ['machine learning', 'communication'], 'employee_experience': [{'company_id': 9, 'designation': 'Chartered loss adjuster', 'salary': 49439, 'skills': 'python, communication'}]}
# {'employee_id': 18, 'employee_name': 'Mrs. Amy Callahan', 'employee_salary': 88571, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'python', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 1, 'designation': 'Surveyor, insurance', 'salary': 101022, 'skills': 'machine learning, communication, SQL'}]}
# {'employee_id': 19, 'employee_name': 'Kayla Mcclure', 'employee_salary': 172151, 'employee_designation': 'Manager', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 6, 'designation': 'Stage manager', 'salary': 84625, 'skills': 'data analysis, machine learning, communication'}]}
# {'employee_id': 20, 'employee_name': 'Becky Carr', 'employee_salary': 199380, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Ambulance person', 'salary': 121643, 'skills': 'machine learning, SQL, data analysis'}]}
# {'employee_id': 21, 'employee_name': 'Craig Madden', 'employee_salary': 190303, 'employee_designation': 'Designer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Doctor, hospital', 'salary': 115429, 'skills': 'java, SQL'}]}
# {'employee_id': 22, 'employee_name': 'Kenneth Richards MD', 'employee_salary': 100713, 'employee_designation': 'Analyst', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 3, 'designation': 'Engineer, site', 'salary': 90959, 'skills': 'machine learning, python'}]}
# {'employee_id': 23, 'employee_name': 'Ivan Howard', 'employee_salary': 151302, 'employee_designation': 'Analyst', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Paramedic', 'salary': 52095, 'skills': 'java, SQL'}]}
# {'employee_id': 24, 'employee_name': 'Andre Harris', 'employee_salary': 167766, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'machine learning', 'python', 'SQL', 'data analysis'], 'employee_experience': [{'company_id': 4, 'designation': 'Dietitian', 'salary': 128709, 'skills': 'SQL'}]}
# {'employee_id': 25, 'employee_name': 'Mark Gallagher', 'employee_salary': 161534, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'communication', 'python'], 'employee_experience': [{'company_id': 1, 'designation': 'Toxicologist', 'salary': 93521, 'skills': 'communication, python, SQL'}]}
# {'employee_id': 26, 'employee_name': 'Krystal Thomas', 'employee_salary': 197518, 'employee_designation': 'Designer', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 5, 'designation': 'Race relations officer', 'salary': 126644, 'skills': 'machine learning, java'}]}
# {'employee_id': 27, 'employee_name': 'Gilbert Davis', 'employee_salary': 71504, 'employee_designation': 'Manager', 'employee_skills': ['python', 'java', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Actor', 'salary': 57628, 'skills': 'java, SQL, python'}]}
# {'employee_id': 28, 'employee_name': 'Laura Petersen', 'employee_salary': 193594, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'data analysis', 'python'], 'employee_experience': [{'company_id': 3, 'designation': 'Human resources officer', 'salary': 34578, 'skills': 'SQL, python'}]}
# {'employee_id': 29, 'employee_name': 'Kevin Bradley', 'employee_salary': 73039, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'java', 'communication', 'python'], 'employee_experience': [{'company_id': 6, 'designation': 'Librarian, public', 'salary': 143582, 'skills': 'data analysis, SQL, java'}]}
# {'employee_id': 30, 'employee_name': 'Ronnie Smith', 'employee_salary': 54343, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'python'], 'employee_experience': [{'company_id': 7, 'designation': 'Toxicologist', 'salary': 66495, 'skills': 'machine learning, communication, python'}]}
# {'employee_id': 31, 'employee_name': 'Travis Arias', 'employee_salary': 127606, 'employee_designation': 'Manager', 'employee_skills': ['machine learning', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Programmer, applications', 'salary': 136215, 'skills': 'python, data analysis'}]}
# {'employee_id': 32, 'employee_name': 'Jennifer Barrett', 'employee_salary': 112351, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'SQL', 'python', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Doctor, hospital', 'salary': 62520, 'skills': 'SQL'}]}
# {'employee_id': 33, 'employee_name': 'Jennifer Anderson', 'employee_salary': 165907, 'employee_designation': 'Designer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 5, 'designation': 'Prison officer', 'salary': 98883, 'skills': 'data analysis'}]}
# {'employee_id': 34, 'employee_name': 'Kevin Carter', 'employee_salary': 58749, 'employee_designation': 'Designer', 'employee_skills': ['python', 'SQL', 'communication', 'java', 'machine learning'], 'employee_experience': [{'company_id': 6, 'designation': 'Commercial/residential surveyor', 'salary': 45243, 'skills': 'SQL, machine learning'}]}
# {'employee_id': 35, 'employee_name': 'Brianna Richard', 'employee_salary': 59489, 'employee_designation': 'Developer', 'employee_skills': ['data analysis', 'java', 'SQL', 'communication'], 'employee_experience': [{'company_id': 2, 'designation': 'Geologist, wellsite', 'salary': 59820, 'skills': 'machine learning, communication, python'}]}
# {'employee_id': 36, 'employee_name': 'Troy Jordan', 'employee_salary': 127744, 'employee_designation': 'Developer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 1, 'designation': 'Engineer, structural', 'salary': 45566, 'skills': 'machine learning, java'}]}
# {'employee_id': 37, 'employee_name': 'Teresa Garcia', 'employee_salary': 63513, 'employee_designation': 'Developer', 'employee_skills': ['python', 'data analysis', 'java', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 7, 'designation': 'Optician, dispensing', 'salary': 121816, 'skills': 'data analysis, communication, python'}]}
# {'employee_id': 38, 'employee_name': 'Patrick Yates', 'employee_salary': 55710, 'employee_designation': 'Designer', 'employee_skills': ['python', 'data analysis', 'communication', 'machine learning'], 'employee_experience': [{'company_id': 6, 'designation': 'Psychologist, counselling', 'salary': 122592, 'skills': 'python, machine learning'}]}
# {'employee_id': 39, 'employee_name': 'Emily Sullivan', 'employee_salary': 106833, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'SQL', 'java', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Therapist, occupational', 'salary': 83177, 'skills': 'java, SQL'}]}
# {'employee_id': 40, 'employee_name': 'Rachel Ramirez', 'employee_salary': 73156, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'SQL'], 'employee_experience': [{'company_id': 8, 'designation': 'Ranger/warden', 'salary': 42921, 'skills': 'machine learning'}]}
# {'employee_id': 41, 'employee_name': 'Karen Thomas', 'employee_salary': 81928, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'SQL', 'communication'], 'employee_experience': [{'company_id': 5, 'designation': 'Merchant navy officer', 'salary': 145713, 'skills': 'SQL'}]}
# {'employee_id': 42, 'employee_name': 'Denise Franklin', 'employee_salary': 51178, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'python', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Health physicist', 'salary': 43920, 'skills': 'machine learning, data analysis'}]}
# {'employee_id': 43, 'employee_name': 'Kimberly Taylor', 'employee_salary': 108615, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'communication'], 'employee_experience': [{'company_id': 7, 'designation': 'Psychiatrist', 'salary': 68450, 'skills': 'java, machine learning, data analysis'}]}
# {'employee_id': 44, 'employee_name': 'Jessica Wagner', 'employee_salary': 56266, 'employee_designation': 'Designer', 'employee_skills': ['python', 'communication'], 'employee_experience': [{'company_id': 5, 'designation': 'Cartographer', 'salary': 70691, 'skills': 'machine learning, SQL, data analysis'}]}
# {'employee_id': 45, 'employee_name': 'David Santos', 'employee_salary': 117494, 'employee_designation': 'Analyst', 'employee_skills': ['communication'], 'employee_experience': [{'company_id': 8, 'designation': 'Teacher, adult education', 'salary': 98847, 'skills': 'machine learning'}]}
# {'employee_id': 46, 'employee_name': 'Tracy Gonzalez', 'employee_salary': 66899, 'employee_designation': 'Developer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 1, 'designation': 'Merchant navy officer', 'salary': 114092, 'skills': 'data analysis, machine learning, python'}]}
# {'employee_id': 47, 'employee_name': 'Anna Hill', 'employee_salary': 135333, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'java', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Housing manager/officer', 'salary': 103464, 'skills': 'machine learning, java, SQL'}]}
# {'employee_id': 48, 'employee_name': 'Amy Dean', 'employee_salary': 128278, 'employee_designation': 'Manager', 'employee_skills': ['python', 'machine learning', 'java', 'data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Mining engineer', 'salary': 136551, 'skills': 'java, communication, SQL'}]}
# {'employee_id': 49, 'employee_name': 'Diane Turner', 'employee_salary': 151076, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'python', 'data analysis'], 'employee_experience': [{'company_id': 8, 'designation': 'Theatre director', 'salary': 66607, 'skills': 'python'}]}
# {'employee_id': 50, 'employee_name': 'Mrs. Amber Dixon', 'employee_salary': 116528, 'employee_designation': 'Developer', 'employee_skills': ['SQL', 'java', 'communication'], 'employee_experience': [{'company_id': 1, 'designation': 'Designer, graphic', 'salary': 103382, 'skills': 'machine learning, SQL'}]}
# {'employee_id': 51, 'employee_name': 'Kayla Hughes', 'employee_salary': 52184, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'python', 'SQL', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Higher education lecturer', 'salary': 90733, 'skills': 'communication, data analysis, SQL'}]}
# {'employee_id': 52, 'employee_name': 'Michelle Mitchell', 'employee_salary': 163147, 'employee_designation': 'Manager', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 3, 'designation': 'Ergonomist', 'salary': 109355, 'skills': 'communication, machine learning'}]}
# {'employee_id': 53, 'employee_name': 'Brian Salazar', 'employee_salary': 190151, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'communication', 'machine learning'], 'employee_experience': [{'company_id': 7, 'designation': 'Lecturer, further education', 'salary': 115356, 'skills': 'python, SQL, machine learning'}]}
# {'employee_id': 54, 'employee_name': 'Bruce Collins', 'employee_salary': 74262, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'machine learning', 'data analysis', 'java', 'python'], 'employee_experience': [{'company_id': 9, 'designation': 'Tour manager', 'salary': 103926, 'skills': 'python'}]}
# {'employee_id': 55, 'employee_name': 'Betty Boyd', 'employee_salary': 54666, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Theatre stage manager', 'salary': 136900, 'skills': 'data analysis, machine learning, java'}]}
# {'employee_id': 56, 'employee_name': 'Brian Fisher', 'employee_salary': 160067, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'communication', 'java', 'data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Regulatory affairs officer', 'salary': 105547, 'skills': 'data analysis'}]}
# {'employee_id': 57, 'employee_name': 'Adriana Mayo', 'employee_salary': 147411, 'employee_designation': 'Developer', 'employee_skills': ['SQL', 'machine learning', 'java', 'python'], 'employee_experience': [{'company_id': 6, 'designation': 'Civil engineer, consulting', 'salary': 96352, 'skills': 'machine learning, java, python'}]}
# {'employee_id': 58, 'employee_name': 'Kristy Mitchell', 'employee_salary': 110764, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'java', 'SQL'], 'employee_experience': [{'company_id': 4, 'designation': 'Child psychotherapist', 'salary': 125818, 'skills': 'communication, java, data analysis'}]}
# {'employee_id': 59, 'employee_name': 'Kimberly Rodriguez', 'employee_salary': 177386, 'employee_designation': 'Designer', 'employee_skills': ['python', 'SQL', 'communication'], 'employee_experience': [{'company_id': 7, 'designation': 'Runner, broadcasting/film/video', 'salary': 67948, 'skills': 'machine learning, java, communication'}]}
# {'employee_id': 60, 'employee_name': 'Matthew Garrett', 'employee_salary': 99816, 'employee_designation': 'Developer', 'employee_skills': ['data analysis', 'communication', 'python'], 'employee_experience': [{'company_id': 10, 'designation': 'Equality and diversity officer', 'salary': 58180, 'skills': 'machine learning, SQL'}]}
# {'employee_id': 61, 'employee_name': 'Rebecca Thompson', 'employee_salary': 106888, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'python', 'java', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Animal technologist', 'salary': 76396, 'skills': 'java'}]}
# {'employee_id': 62, 'employee_name': 'Jacqueline Andrews', 'employee_salary': 107821, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'java'], 'employee_experience': [{'company_id': 10, 'designation': 'TEFL teacher', 'salary': 140209, 'skills': 'java, SQL'}]}
# {'employee_id': 63, 'employee_name': 'Whitney Gilbert', 'employee_salary': 140547, 'employee_designation': 'Designer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 1, 'designation': 'General practice doctor', 'salary': 89594, 'skills': 'SQL, python, data analysis'}]}
# {'employee_id': 64, 'employee_name': 'Shannon Sanders', 'employee_salary': 124101, 'employee_designation': 'Manager', 'employee_skills': ['python', 'machine learning', 'data analysis', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Aid worker', 'salary': 71045, 'skills': 'machine learning, communication, data analysis'}]}
# {'employee_id': 65, 'employee_name': 'Ashley Griffin', 'employee_salary': 87370, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'machine learning', 'java', 'SQL'], 'employee_experience': [{'company_id': 7, 'designation': 'Sales executive', 'salary': 65397, 'skills': 'SQL, python'}]}
# {'employee_id': 66, 'employee_name': 'Daniel Ballard', 'employee_salary': 164898, 'employee_designation': 'Designer', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Agricultural engineer', 'salary': 38131, 'skills': 'machine learning'}]}
# {'employee_id': 67, 'employee_name': 'Meagan Richardson', 'employee_salary': 94866, 'employee_designation': 'Analyst', 'employee_skills': ['java', 'communication'], 'employee_experience': [{'company_id': 10, 'designation': 'Insurance claims handler', 'salary': 114262, 'skills': 'python, communication, data analysis'}]}
# {'employee_id': 68, 'employee_name': 'Veronica Harris', 'employee_salary': 197468, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'java', 'communication', 'SQL'], 'employee_experience': [{'company_id': 7, 'designation': 'Social researcher', 'salary': 142107, 'skills': 'java, python, communication'}]}
# {'employee_id': 69, 'employee_name': 'Michael Chang', 'employee_salary': 151122, 'employee_designation': 'Manager', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 5, 'designation': 'Brewing technologist', 'salary': 77431, 'skills': 'SQL, machine learning, data analysis'}]}
# {'employee_id': 70, 'employee_name': 'Angela Johnson', 'employee_salary': 78222, 'employee_designation': 'Designer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Furniture designer', 'salary': 39638, 'skills': 'python'}]}
# {'employee_id': 71, 'employee_name': 'Sarah Lee', 'employee_salary': 146879, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'java', 'communication', 'python', 'machine learning'], 'employee_experience': [{'company_id': 8, 'designation': 'Accountant, chartered certified', 'salary': 75825, 'skills': 'data analysis, python, java'}]}
# {'employee_id': 72, 'employee_name': 'Kimberly Saunders', 'employee_salary': 128147, 'employee_designation': 'Designer', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 4, 'designation': 'Scientist, research (medical)', 'salary': 94289, 'skills': 'java, data analysis, machine learning'}]}
# {'employee_id': 73, 'employee_name': 'Martin Mercado', 'employee_salary': 65167, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'java', 'data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Textile designer', 'salary': 91164, 'skills': 'machine learning'}]}
# {'employee_id': 74, 'employee_name': 'Lindsay Ponce', 'employee_salary': 199471, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'communication', 'data analysis'], 'employee_experience': [{'company_id': 6, 'designation': 'Orthoptist', 'salary': 143582, 'skills': 'communication, python'}]}
# {'employee_id': 75, 'employee_name': 'Sarah Jackson', 'employee_salary': 80917, 'employee_designation': 'Manager', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 7, 'designation': 'Ergonomist', 'salary': 68978, 'skills': 'java, communication'}]}
# {'employee_id': 76, 'employee_name': 'Jordan Massey', 'employee_salary': 146108, 'employee_designation': 'Developer', 'employee_skills': ['python', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 7, 'designation': 'Industrial/product designer', 'salary': 51615, 'skills': 'python'}]}
# {'employee_id': 77, 'employee_name': 'Corey Parker', 'employee_salary': 159872, 'employee_designation': 'Manager', 'employee_skills': ['python', 'data analysis', 'SQL', 'machine learning', 'java'], 'employee_experience': [{'company_id': 6, 'designation': 'Scientific laboratory technician', 'salary': 110761, 'skills': 'SQL, java, data analysis'}]}
# {'employee_id': 78, 'employee_name': 'Gary Becker', 'employee_salary': 73384, 'employee_designation': 'Developer', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 6, 'designation': 'Engineer, broadcasting (operations)', 'salary': 88669, 'skills': 'machine learning, SQL'}]}
# {'employee_id': 79, 'employee_name': 'David Kramer', 'employee_salary': 138611, 'employee_designation': 'Developer', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Database administrator', 'salary': 67789, 'skills': 'python'}]}
# {'employee_id': 80, 'employee_name': 'Charles Jones', 'employee_salary': 68731, 'employee_designation': 'Manager', 'employee_skills': ['java', 'SQL', 'python'], 'employee_experience': [{'company_id': 2, 'designation': 'Scientific laboratory technician', 'salary': 137332, 'skills': 'java'}]}
# {'employee_id': 81, 'employee_name': 'Christopher Browning', 'employee_salary': 151335, 'employee_designation': 'Manager', 'employee_skills': ['python', 'machine learning', 'SQL', 'communication'], 'employee_experience': [{'company_id': 10, 'designation': 'Best boy', 'salary': 43371, 'skills': 'data analysis'}]}
# {'employee_id': 82, 'employee_name': 'Juan Bender', 'employee_salary': 87873, 'employee_designation': 'Developer', 'employee_skills': ['data analysis', 'machine learning'], 'employee_experience': [{'company_id': 8, 'designation': 'Forensic psychologist', 'salary': 112845, 'skills': 'communication'}]}
# {'employee_id': 83, 'employee_name': 'David Reeves', 'employee_salary': 174125, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'java', 'communication', 'python'], 'employee_experience': [{'company_id': 4, 'designation': 'Furniture designer', 'salary': 115121, 'skills': 'java'}]}
# {'employee_id': 84, 'employee_name': 'Michelle Rodriguez', 'employee_salary': 141313, 'employee_designation': 'Analyst', 'employee_skills': ['SQL', 'data analysis', 'python'], 'employee_experience': [{'company_id': 8, 'designation': 'Immunologist', 'salary': 119919, 'skills': 'data analysis'}]}
# {'employee_id': 85, 'employee_name': 'John West', 'employee_salary': 136987, 'employee_designation': 'Manager', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 3, 'designation': 'Museum/gallery exhibitions officer', 'salary': 139097, 'skills': 'machine learning, python'}]}
# {'employee_id': 86, 'employee_name': 'Michelle Clark', 'employee_salary': 185643, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'python', 'communication', 'SQL', 'java'], 'employee_experience': [{'company_id': 2, 'designation': 'Regulatory affairs officer', 'salary': 75716, 'skills': 'communication, machine learning'}]}
# {'employee_id': 87, 'employee_name': 'Kimberly Santiago', 'employee_salary': 195483, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 9, 'designation': 'Engineer, site', 'salary': 143120, 'skills': 'python, data analysis, communication'}]}
# {'employee_id': 88, 'employee_name': 'Gina Mitchell', 'employee_salary': 166808, 'employee_designation': 'Developer', 'employee_skills': ['python', 'data analysis', 'SQL', 'machine learning'], 'employee_experience': [{'company_id': 3, 'designation': 'Education officer, museum', 'salary': 100239, 'skills': 'python'}]}
# {'employee_id': 89, 'employee_name': 'Jason Burton', 'employee_salary': 189341, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'communication', 'data analysis', 'SQL'], 'employee_experience': [{'company_id': 6, 'designation': 'Tax adviser', 'salary': 134363, 'skills': 'machine learning'}]}
# {'employee_id': 90, 'employee_name': 'Steven Hernandez', 'employee_salary': 92460, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'java', 'SQL', 'python'], 'employee_experience': [{'company_id': 10, 'designation': 'Set designer', 'salary': 135832, 'skills': 'java, communication, machine learning'}]}
# {'employee_id': 91, 'employee_name': 'Abigail Collins', 'employee_salary': 97142, 'employee_designation': 'Analyst', 'employee_skills': ['SQL', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 5, 'designation': 'Advertising copywriter', 'salary': 116703, 'skills': 'SQL, communication'}]}
# {'employee_id': 92, 'employee_name': 'Craig Hudson', 'employee_salary': 152774, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'SQL'], 'employee_experience': [{'company_id': 4, 'designation': 'Local government officer', 'salary': 125361, 'skills': 'communication, data analysis'}]}
# {'employee_id': 93, 'employee_name': 'Dylan Erickson', 'employee_salary': 63940, 'employee_designation': 'Manager', 'employee_skills': ['java', 'machine learning', 'python'], 'employee_experience': [{'company_id': 2, 'designation': 'Database administrator', 'salary': 37777, 'skills': 'machine learning'}]}
# {'employee_id': 94, 'employee_name': 'William Moran', 'employee_salary': 185350, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'data analysis', 'java', 'python', 'machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Lexicographer', 'salary': 120474, 'skills': 'communication, machine learning'}]}
# {'employee_id': 95, 'employee_name': 'John Gonzalez', 'employee_salary': 121547, 'employee_designation': 'Manager', 'employee_skills': ['python', 'data analysis'], 'employee_experience': [{'company_id': 7, 'designation': 'Medical illustrator', 'salary': 99863, 'skills': 'java, python, machine learning'}]}
# {'employee_id': 96, 'employee_name': 'Glenda Ramirez', 'employee_salary': 198788, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'communication', 'SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Chiropodist', 'salary': 42245, 'skills': 'data analysis, python, communication'}]}
# {'employee_id': 97, 'employee_name': 'David Guzman', 'employee_salary': 183268, 'employee_designation': 'Developer', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 2, 'designation': 'Data scientist', 'salary': 126929, 'skills': 'data analysis, SQL, machine learning'}]}
# {'employee_id': 98, 'employee_name': 'Arthur Lopez', 'employee_salary': 55333, 'employee_designation': 'Analyst', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 7, 'designation': 'Producer, radio', 'salary': 70595, 'skills': 'java, python'}]}
# {'employee_id': 99, 'employee_name': 'Matthew Mitchell', 'employee_salary': 155165, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'data analysis'], 'employee_experience': [{'company_id': 4, 'designation': 'Equities trader', 'salary': 146573, 'skills': 'communication, data analysis'}]}
# {'employee_id': 100, 'employee_name': 'Megan Williams', 'employee_salary': 52269, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'python', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'IT sales professional', 'salary': 119585, 'skills': 'machine learning, java'}]}
# {'employee_id': 101, 'employee_name': 'Kimberly Scott', 'employee_salary': 119925, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'python', 'SQL', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 10, 'designation': 'Horticultural therapist', 'salary': 102427, 'skills': 'machine learning, SQL, data analysis'}]}
# {'employee_id': 102, 'employee_name': 'Alison Floyd', 'employee_salary': 130454, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'machine learning'], 'employee_experience': [{'company_id': 8, 'designation': 'Designer, television/film set', 'salary': 34737, 'skills': 'data analysis, python, SQL'}]}
# {'employee_id': 103, 'employee_name': 'Kevin Bright', 'employee_salary': 178550, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 5, 'designation': 'Equities trader', 'salary': 117635, 'skills': 'java, communication'}]}
# {'employee_id': 104, 'employee_name': 'Kimberly Rodgers', 'employee_salary': 80998, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'SQL', 'java', 'communication', 'machine learning'], 'employee_experience': [{'company_id': 7, 'designation': 'Operations geologist', 'salary': 72167, 'skills': 'SQL, java'}]}
# {'employee_id': 105, 'employee_name': 'James Cooper', 'employee_salary': 89109, 'employee_designation': 'Developer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 4, 'designation': 'Archivist', 'salary': 81800, 'skills': 'machine learning, SQL, communication'}]}
# {'employee_id': 106, 'employee_name': 'Brittany Little', 'employee_salary': 180007, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'machine learning', 'java'], 'employee_experience': [{'company_id': 7, 'designation': 'Acupuncturist', 'salary': 138514, 'skills': 'data analysis, SQL, communication'}]}
# {'employee_id': 107, 'employee_name': 'Paul Lang', 'employee_salary': 72769, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 5, 'designation': 'Medical illustrator', 'salary': 47409, 'skills': 'SQL, machine learning'}]}
# {'employee_id': 108, 'employee_name': 'Rebekah Payne', 'employee_salary': 86487, 'employee_designation': 'Designer', 'employee_skills': ['machine learning', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Scientist, forensic', 'salary': 136579, 'skills': 'data analysis, machine learning, python'}]}
# {'employee_id': 109, 'employee_name': 'Randy Pierce', 'employee_salary': 114320, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 4, 'designation': 'Museum/gallery conservator', 'salary': 78659, 'skills': 'python'}]}
# {'employee_id': 110, 'employee_name': 'Elizabeth Caldwell', 'employee_salary': 116995, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'java', 'machine learning'], 'employee_experience': [{'company_id': 1, 'designation': 'Journalist, newspaper', 'salary': 78977, 'skills': 'python, data analysis, machine learning'}]}
# {'employee_id': 111, 'employee_name': 'Gail Delacruz', 'employee_salary': 157049, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'java'], 'employee_experience': [{'company_id': 7, 'designation': 'Horticultural therapist', 'salary': 50513, 'skills': 'data analysis'}]}
# {'employee_id': 112, 'employee_name': 'Sergio Welch', 'employee_salary': 128641, 'employee_designation': 'Developer', 'employee_skills': ['SQL', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Estate agent', 'salary': 91775, 'skills': 'data analysis, python'}]}
# {'employee_id': 113, 'employee_name': 'Victoria Duncan', 'employee_salary': 176549, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'java', 'python'], 'employee_experience': [{'company_id': 3, 'designation': 'Telecommunications researcher', 'salary': 108069, 'skills': 'SQL'}]}
# {'employee_id': 114, 'employee_name': 'Carmen Rhodes', 'employee_salary': 89246, 'employee_designation': 'Analyst', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 2, 'designation': 'Dance movement psychotherapist', 'salary': 125946, 'skills': 'python, data analysis, java'}]}
# {'employee_id': 115, 'employee_name': 'Charles Snyder', 'employee_salary': 142564, 'employee_designation': 'Analyst', 'employee_skills': ['SQL', 'data analysis', 'python', 'machine learning'], 'employee_experience': [{'company_id': 1, 'designation': 'Retail buyer', 'salary': 97772, 'skills': 'data analysis'}]}
# {'employee_id': 116, 'employee_name': 'Beverly Harmon', 'employee_salary': 197800, 'employee_designation': 'Manager', 'employee_skills': ['python', 'data analysis'], 'employee_experience': [{'company_id': 5, 'designation': 'English as a foreign language teacher', 'salary': 77952, 'skills': 'java, machine learning, communication'}]}
# {'employee_id': 117, 'employee_name': 'Jeffery Thompson', 'employee_salary': 141422, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'java', 'SQL', 'python', 'machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Psychologist, prison and probation services', 'salary': 117773, 'skills': 'java'}]}
# {'employee_id': 118, 'employee_name': 'Paula Raymond', 'employee_salary': 56196, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'data analysis', 'java', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Wellsite geologist', 'salary': 94222, 'skills': 'communication, python'}]}
# {'employee_id': 119, 'employee_name': 'Jason Mack', 'employee_salary': 121926, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'machine learning', 'SQL', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Land/geomatics surveyor', 'salary': 144584, 'skills': 'data analysis, SQL'}]}
# {'employee_id': 120, 'employee_name': 'Judy Williams', 'employee_salary': 186071, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'java', 'data analysis'], 'employee_experience': [{'company_id': 8, 'designation': 'Research officer, political party', 'salary': 105782, 'skills': 'machine learning, python, communication'}]}
# {'employee_id': 121, 'employee_name': 'Jennifer Donaldson', 'employee_salary': 167651, 'employee_designation': 'Manager', 'employee_skills': ['python', 'java', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 9, 'designation': 'Surveyor, commercial/residential', 'salary': 99644, 'skills': 'SQL, communication, python'}]}
# {'employee_id': 122, 'employee_name': 'Terry Bell', 'employee_salary': 69406, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'machine learning', 'java', 'data analysis', 'SQL'], 'employee_experience': [{'company_id': 8, 'designation': 'Consulting civil engineer', 'salary': 75826, 'skills': 'communication'}]}
# {'employee_id': 123, 'employee_name': 'Joy Best', 'employee_salary': 193607, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 10, 'designation': 'Chief Operating Officer', 'salary': 129300, 'skills': 'SQL'}]}
# {'employee_id': 124, 'employee_name': 'Caitlin Stone', 'employee_salary': 132636, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'communication'], 'employee_experience': [{'company_id': 4, 'designation': 'Dance movement psychotherapist', 'salary': 97049, 'skills': 'python, data analysis, machine learning'}]}
# {'employee_id': 125, 'employee_name': 'Susan Turner', 'employee_salary': 76165, 'employee_designation': 'Developer', 'employee_skills': ['communication', 'SQL', 'python'], 'employee_experience': [{'company_id': 7, 'designation': 'Chief Operating Officer', 'salary': 144097, 'skills': 'python'}]}
# {'employee_id': 126, 'employee_name': 'Daniel Luna', 'employee_salary': 71773, 'employee_designation': 'Developer', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 4, 'designation': 'Television camera operator', 'salary': 92443, 'skills': 'python'}]}
# {'employee_id': 127, 'employee_name': 'John Ford', 'employee_salary': 182011, 'employee_designation': 'Designer', 'employee_skills': ['machine learning', 'data analysis'], 'employee_experience': [{'company_id': 6, 'designation': 'Museum/gallery exhibitions officer', 'salary': 91805, 'skills': 'python'}]}
# {'employee_id': 128, 'employee_name': 'Michael Hall', 'employee_salary': 152442, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'communication', 'data analysis', 'machine learning'], 'employee_experience': [{'company_id': 5, 'designation': 'Operational researcher', 'salary': 144808, 'skills': 'python'}]}
# {'employee_id': 129, 'employee_name': 'James Carson', 'employee_salary': 114217, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'python', 'machine learning', 'data analysis'], 'employee_experience': [{'company_id': 5, 'designation': 'Public librarian', 'salary': 80075, 'skills': 'communication, java, machine learning'}]}
# {'employee_id': 130, 'employee_name': 'Valerie King', 'employee_salary': 81715, 'employee_designation': 'Developer', 'employee_skills': ['SQL', 'machine learning', 'communication', 'java'], 'employee_experience': [{'company_id': 10, 'designation': 'Therapist, music', 'salary': 109922, 'skills': 'java, machine learning'}]}
# {'employee_id': 131, 'employee_name': 'Michael Warner', 'employee_salary': 100698, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'python', 'machine learning'], 'employee_experience': [{'company_id': 9, 'designation': 'Technical author', 'salary': 55409, 'skills': 'python, SQL, data analysis'}]}
# {'employee_id': 132, 'employee_name': 'Tammy French', 'employee_salary': 144526, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'machine learning', 'python', 'java', 'communication'], 'employee_experience': [{'company_id': 2, 'designation': 'Copywriter, advertising', 'salary': 130205, 'skills': 'SQL, machine learning'}]}
# {'employee_id': 133, 'employee_name': 'Jennifer Rollins', 'employee_salary': 157531, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'data analysis', 'python'], 'employee_experience': [{'company_id': 1, 'designation': 'Camera operator', 'salary': 141736, 'skills': 'communication'}]}
# {'employee_id': 134, 'employee_name': 'David Dyer', 'employee_salary': 50971, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Control and instrumentation engineer', 'salary': 33452, 'skills': 'java, communication, data analysis'}]}
# {'employee_id': 135, 'employee_name': 'Shelby Reynolds', 'employee_salary': 95777, 'employee_designation': 'Manager', 'employee_skills': ['python', 'SQL', 'data analysis', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 5, 'designation': 'Warden/ranger', 'salary': 77336, 'skills': 'communication, data analysis'}]}
# {'employee_id': 136, 'employee_name': 'Erin Johnson', 'employee_salary': 69988, 'employee_designation': 'Developer', 'employee_skills': ['python', 'SQL', 'communication', 'data analysis', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Chief Financial Officer', 'salary': 38203, 'skills': 'machine learning, communication, python'}]}
# {'employee_id': 137, 'employee_name': 'Elizabeth Perry', 'employee_salary': 162055, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'machine learning', 'communication'], 'employee_experience': [{'company_id': 8, 'designation': 'Therapeutic radiographer', 'salary': 114526, 'skills': 'SQL'}]}
# {'employee_id': 138, 'employee_name': 'Derrick Fisher', 'employee_salary': 52256, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'SQL'], 'employee_experience': [{'company_id': 10, 'designation': 'Dramatherapist', 'salary': 139669, 'skills': 'python, data analysis, machine learning'}]}
# {'employee_id': 139, 'employee_name': 'Casey Mcgee', 'employee_salary': 112459, 'employee_designation': 'Designer', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 1, 'designation': 'Television production assistant', 'salary': 66549, 'skills': 'machine learning'}]}
# {'employee_id': 140, 'employee_name': 'Dana Johnson', 'employee_salary': 63832, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'SQL', 'machine learning', 'python', 'java'], 'employee_experience': [{'company_id': 5, 'designation': 'Scientist, water quality', 'salary': 35833, 'skills': 'machine learning'}]}
# {'employee_id': 141, 'employee_name': 'Theresa Jones', 'employee_salary': 140505, 'employee_designation': 'Manager', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 8, 'designation': 'Actor', 'salary': 89893, 'skills': 'python, SQL, data analysis'}]}
# {'employee_id': 142, 'employee_name': 'Nicole Harrison', 'employee_salary': 66707, 'employee_designation': 'Designer', 'employee_skills': ['java', 'data analysis', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 5, 'designation': 'Musician', 'salary': 106410, 'skills': 'machine learning, java'}]}
# {'employee_id': 143, 'employee_name': 'Linda Evans', 'employee_salary': 131472, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning'], 'employee_experience': [{'company_id': 8, 'designation': 'Accountant, chartered', 'salary': 53565, 'skills': 'communication, java'}]}
# {'employee_id': 144, 'employee_name': 'Hailey Harris', 'employee_salary': 60591, 'employee_designation': 'Manager', 'employee_skills': ['machine learning', 'SQL', 'communication', 'data analysis'], 'employee_experience': [{'company_id': 6, 'designation': 'Sales professional, IT', 'salary': 131280, 'skills': 'data analysis'}]}
# {'employee_id': 145, 'employee_name': 'Henry Ruiz', 'employee_salary': 164333, 'employee_designation': 'Analyst', 'employee_skills': ['SQL', 'data analysis', 'communication', 'python', 'machine learning'], 'employee_experience': [{'company_id': 10, 'designation': 'Lawyer', 'salary': 66061, 'skills': 'SQL, data analysis'}]}
# {'employee_id': 146, 'employee_name': 'Stacy Beard', 'employee_salary': 164528, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'java', 'SQL', 'python', 'communication'], 'employee_experience': [{'company_id': 1, 'designation': 'Local government officer', 'salary': 130279, 'skills': 'SQL'}]}
# {'employee_id': 147, 'employee_name': 'Nicole Cobb', 'employee_salary': 76680, 'employee_designation': 'Designer', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 3, 'designation': 'Mining engineer', 'salary': 39458, 'skills': 'data analysis'}]}
# {'employee_id': 148, 'employee_name': 'Diana Curtis', 'employee_salary': 125717, 'employee_designation': 'Manager', 'employee_skills': ['java', 'communication', 'SQL'], 'employee_experience': [{'company_id': 7, 'designation': 'IT technical support officer', 'salary': 37061, 'skills': 'SQL'}]}
# {'employee_id': 149, 'employee_name': 'Brian Alvarez', 'employee_salary': 147839, 'employee_designation': 'Designer', 'employee_skills': ['machine learning', 'SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Community education officer', 'salary': 72313, 'skills': 'machine learning, python, communication'}]}
# {'employee_id': 150, 'employee_name': 'Jeffery Avery', 'employee_salary': 172668, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'SQL', 'communication', 'java'], 'employee_experience': [{'company_id': 4, 'designation': 'Therapist, occupational', 'salary': 60151, 'skills': 'SQL, python'}]}
# {'employee_id': 151, 'employee_name': 'Kelly Munoz', 'employee_salary': 127766, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Engineer, land', 'salary': 84222, 'skills': 'python'}]}
# {'employee_id': 152, 'employee_name': 'Laura Martin MD', 'employee_salary': 70846, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'data analysis', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Solicitor, Scotland', 'salary': 58649, 'skills': 'communication, python, data analysis'}]}
# {'employee_id': 153, 'employee_name': 'Marissa Ford', 'employee_salary': 193190, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'data analysis', 'SQL'], 'employee_experience': [{'company_id': 7, 'designation': 'Newspaper journalist', 'salary': 127509, 'skills': 'python'}]}
# ...
# {'employee_id': 950, 'employee_name': 'Richard Garcia', 'employee_salary': 82968, 'employee_designation': 'Manager', 'employee_skills': ['python', 'SQL', 'data analysis', 'java'], 'employee_experience': [{'company_id': 1, 'designation': 'Visual merchandiser', 'salary': 43079, 'skills': 'machine learning'}]}
# {'employee_id': 951, 'employee_name': 'Joshua Reyes', 'employee_salary': 73925, 'employee_designation': 'Designer', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Surgeon', 'salary': 122493, 'skills': 'java, python'}]}
# {'employee_id': 952, 'employee_name': 'Lori Mercer', 'employee_salary': 165910, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'SQL', 'java', 'data analysis'], 'employee_experience': [{'company_id': 8, 'designation': 'Information systems manager', 'salary': 98107, 'skills': 'python, data analysis'}]}
# {'employee_id': 953, 'employee_name': 'Gavin Carlson', 'employee_salary': 185823, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'communication', 'data analysis', 'python'], 'employee_experience': [{'company_id': 8, 'designation': 'Systems analyst', 'salary': 128098, 'skills': 'data analysis'}]}
# {'employee_id': 954, 'employee_name': 'Ashley Murphy', 'employee_salary': 180448, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'communication', 'SQL', 'java'], 'employee_experience': [{'company_id': 10, 'designation': 'Banker', 'salary': 132769, 'skills': 'python, communication, machine learning'}]}
# {'employee_id': 955, 'employee_name': 'Michael Lopez', 'employee_salary': 118097, 'employee_designation': 'Designer', 'employee_skills': ['SQL', 'data analysis'], 'employee_experience': [{'company_id': 8, 'designation': 'Textile designer', 'salary': 137052, 'skills': 'SQL, python'}]}
# {'employee_id': 956, 'employee_name': 'Daniel Brown', 'employee_salary': 60240, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'java', 'communication', 'python', 'machine learning'], 'employee_experience': [{'company_id': 5, 'designation': 'Quality manager', 'salary': 106626, 'skills': 'SQL'}]}
# {'employee_id': 957, 'employee_name': 'Michael Simmons', 'employee_salary': 177112, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'machine learning', 'data analysis', 'communication'], 'employee_experience': [{'company_id': 8, 'designation': 'Product manager', 'salary': 98188, 'skills': 'data analysis, communication'}]}
# {'employee_id': 958, 'employee_name': 'Malik Olsen', 'employee_salary': 148950, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'data analysis', 'java', 'SQL'], 'employee_experience': [{'company_id': 10, 'designation': 'Journalist, magazine', 'salary': 59279, 'skills': 'SQL'}]}
# {'employee_id': 959, 'employee_name': 'Sheryl Hickman', 'employee_salary': 137976, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'java', 'data analysis', 'communication', 'python'], 'employee_experience': [{'company_id': 8, 'designation': 'Actor', 'salary': 32720, 'skills': 'data analysis, communication, SQL'}]}
# {'employee_id': 960, 'employee_name': 'Dominique Vance', 'employee_salary': 191863, 'employee_designation': 'Analyst', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 7, 'designation': 'Solicitor, Scotland', 'salary': 41001, 'skills': 'java, SQL, python'}]}
# {'employee_id': 961, 'employee_name': 'Kayla Simon', 'employee_salary': 168119, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'data analysis', 'SQL'], 'employee_experience': [{'company_id': 1, 'designation': 'Consulting civil engineer', 'salary': 30506, 'skills': 'SQL, data analysis'}]}
# {'employee_id': 962, 'employee_name': 'Nichole Vega MD', 'employee_salary': 105972, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'python', 'java'], 'employee_experience': [{'company_id': 6, 'designation': 'Teacher, English as a foreign language', 'salary': 131032, 'skills': 'communication'}]}
# {'employee_id': 963, 'employee_name': 'Crystal Anderson', 'employee_salary': 119935, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'machine learning', 'SQL', 'java'], 'employee_experience': [{'company_id': 6, 'designation': 'Sports therapist', 'salary': 47293, 'skills': 'data analysis, machine learning, SQL'}]}
# {'employee_id': 964, 'employee_name': 'Connie Ellis', 'employee_salary': 63245, 'employee_designation': 'Manager', 'employee_skills': ['machine learning', 'java', 'communication', 'python', 'SQL'], 'employee_experience': [{'company_id': 1, 'designation': 'Psychiatrist', 'salary': 73894, 'skills': 'java, SQL'}]}
# {'employee_id': 965, 'employee_name': 'Sherri Castaneda', 'employee_salary': 147649, 'employee_designation': 'Analyst', 'employee_skills': ['java', 'machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Police officer', 'salary': 69890, 'skills': 'communication, data analysis, machine learning'}]}
# {'employee_id': 966, 'employee_name': 'Kimberly James', 'employee_salary': 193749, 'employee_designation': 'Manager', 'employee_skills': ['python', 'SQL', 'data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Chief of Staff', 'salary': 94333, 'skills': 'data analysis'}]}
# {'employee_id': 967, 'employee_name': 'John Tyler', 'employee_salary': 100794, 'employee_designation': 'Developer', 'employee_skills': ['python', 'machine learning'], 'employee_experience': [{'company_id': 10, 'designation': 'Scientist, research (maths)', 'salary': 96816, 'skills': 'communication, java, data analysis'}]}
# {'employee_id': 968, 'employee_name': 'Joyce Nguyen', 'employee_salary': 101326, 'employee_designation': 'Designer', 'employee_skills': ['machine learning', 'java'], 'employee_experience': [{'company_id': 2, 'designation': 'Risk analyst', 'salary': 65434, 'skills': 'communication, machine learning'}]}
# {'employee_id': 969, 'employee_name': 'Sydney Hoffman', 'employee_salary': 186421, 'employee_designation': 'Designer', 'employee_skills': ['java', 'SQL', 'machine learning'], 'employee_experience': [{'company_id': 2, 'designation': 'Education officer, environmental', 'salary': 124441, 'skills': 'data analysis, SQL, java'}]}
# {'employee_id': 970, 'employee_name': 'Samantha Mason', 'employee_salary': 58823, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'java', 'SQL'], 'employee_experience': [{'company_id': 6, 'designation': 'Higher education lecturer', 'salary': 108313, 'skills': 'communication, java'}]}
# {'employee_id': 971, 'employee_name': 'Nathan Kelly', 'employee_salary': 56887, 'employee_designation': 'Developer', 'employee_skills': ['python', 'machine learning'], 'employee_experience': [{'company_id': 10, 'designation': 'Equality and diversity officer', 'salary': 71894, 'skills': 'machine learning, python, SQL'}]}
# {'employee_id': 972, 'employee_name': 'Brandy Velasquez', 'employee_salary': 121002, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'data analysis', 'SQL', 'python'], 'employee_experience': [{'company_id': 3, 'designation': 'Event organiser', 'salary': 102720, 'skills': 'java'}]}
# {'employee_id': 973, 'employee_name': 'Linda May', 'employee_salary': 147659, 'employee_designation': 'Analyst', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 10, 'designation': 'Journalist, magazine', 'salary': 39636, 'skills': 'communication, data analysis, machine learning'}]}
# {'employee_id': 974, 'employee_name': 'Danielle Reed', 'employee_salary': 186963, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'machine learning', 'python', 'SQL', 'java'], 'employee_experience': [{'company_id': 5, 'designation': 'Health physicist', 'salary': 57178, 'skills': 'java'}]}
# {'employee_id': 975, 'employee_name': 'Matthew Castro', 'employee_salary': 88419, 'employee_designation': 'Designer', 'employee_skills': ['python', 'data analysis', 'communication', 'java'], 'employee_experience': [{'company_id': 9, 'designation': 'Hydrologist', 'salary': 149364, 'skills': 'communication, SQL, machine learning'}]}
# {'employee_id': 976, 'employee_name': 'Thomas Castro', 'employee_salary': 170770, 'employee_designation': 'Manager', 'employee_skills': ['data analysis', 'python'], 'employee_experience': [{'company_id': 2, 'designation': 'Mining engineer', 'salary': 89927, 'skills': 'data analysis'}]}
# {'employee_id': 977, 'employee_name': 'Kevin Barry', 'employee_salary': 187688, 'employee_designation': 'Developer', 'employee_skills': ['machine learning', 'java'], 'employee_experience': [{'company_id': 4, 'designation': 'Education officer, community', 'salary': 137182, 'skills': 'python'}]}
# {'employee_id': 978, 'employee_name': 'David Martinez', 'employee_salary': 176898, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'machine learning', 'communication', 'java'], 'employee_experience': [{'company_id': 8, 'designation': 'Science writer', 'salary': 106443, 'skills': 'machine learning, data analysis, java'}]}
# {'employee_id': 979, 'employee_name': 'Dave Smith', 'employee_salary': 55868, 'employee_designation': 'Developer', 'employee_skills': ['communication'], 'employee_experience': [{'company_id': 2, 'designation': 'Armed forces training and education officer', 'salary': 61146, 'skills': 'data analysis, communication'}]}
# {'employee_id': 980, 'employee_name': 'Alexander Tran', 'employee_salary': 104030, 'employee_designation': 'Developer', 'employee_skills': ['java', 'SQL', 'machine learning', 'python', 'data analysis'], 'employee_experience': [{'company_id': 9, 'designation': 'Therapist, occupational', 'salary': 123477, 'skills': 'SQL'}]}
# {'employee_id': 981, 'employee_name': 'Christopher Miller', 'employee_salary': 152551, 'employee_designation': 'Designer', 'employee_skills': ['communication'], 'employee_experience': [{'company_id': 8, 'designation': 'Pilot, airline', 'salary': 106542, 'skills': 'SQL, java'}]}
# {'employee_id': 982, 'employee_name': 'Kayla Diaz', 'employee_salary': 177626, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'SQL', 'python', 'java'], 'employee_experience': [{'company_id': 3, 'designation': 'Mining engineer', 'salary': 34803, 'skills': 'communication, java'}]}
# {'employee_id': 983, 'employee_name': 'Jamie Atkins', 'employee_salary': 167666, 'employee_designation': 'Manager', 'employee_skills': ['communication', 'java'], 'employee_experience': [{'company_id': 2, 'designation': 'Clinical research associate', 'salary': 76159, 'skills': 'python, SQL, data analysis'}]}
# {'employee_id': 984, 'employee_name': 'Andrea Lopez', 'employee_salary': 81792, 'employee_designation': 'Analyst', 'employee_skills': ['java', 'python', 'data analysis', 'machine learning', 'SQL'], 'employee_experience': [{'company_id': 2, 'designation': 'Product/process development scientist', 'salary': 34311, 'skills': 'communication, data analysis'}]}
# {'employee_id': 985, 'employee_name': 'Michael Smith', 'employee_salary': 164307, 'employee_designation': 'Designer', 'employee_skills': ['python', 'SQL', 'communication', 'java', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Medical technical officer', 'salary': 143552, 'skills': 'communication, java'}]}
# {'employee_id': 986, 'employee_name': 'John Simon', 'employee_salary': 118934, 'employee_designation': 'Manager', 'employee_skills': ['SQL', 'machine learning'], 'employee_experience': [{'company_id': 1, 'designation': 'Advertising art director', 'salary': 115175, 'skills': 'communication, machine learning'}]}
# {'employee_id': 987, 'employee_name': 'Jennifer Myers', 'employee_salary': 118659, 'employee_designation': 'Developer', 'employee_skills': ['data analysis', 'communication', 'SQL', 'java'], 'employee_experience': [{'company_id': 3, 'designation': 'Fish farm manager', 'salary': 91400, 'skills': 'communication, data analysis, python'}]}
# {'employee_id': 988, 'employee_name': 'Paul Todd', 'employee_salary': 139088, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 10, 'designation': 'Designer, interior/spatial', 'salary': 112686, 'skills': 'data analysis, python, java'}]}
# {'employee_id': 989, 'employee_name': 'Tony Stewart', 'employee_salary': 78417, 'employee_designation': 'Designer', 'employee_skills': ['python', 'SQL'], 'employee_experience': [{'company_id': 1, 'designation': 'Site engineer', 'salary': 79066, 'skills': 'SQL, java, data analysis'}]}
# {'employee_id': 990, 'employee_name': 'Jerry Wilkinson', 'employee_salary': 173997, 'employee_designation': 'Manager', 'employee_skills': ['SQL'], 'employee_experience': [{'company_id': 5, 'designation': 'Engineer, aeronautical', 'salary': 94363, 'skills': 'machine learning, SQL'}]}
# {'employee_id': 991, 'employee_name': 'Ashley Fernandez', 'employee_salary': 150730, 'employee_designation': 'Analyst', 'employee_skills': ['communication', 'SQL'], 'employee_experience': [{'company_id': 3, 'designation': 'Exercise physiologist', 'salary': 63892, 'skills': 'java'}]}
# {'employee_id': 992, 'employee_name': 'Brenda Berry', 'employee_salary': 145152, 'employee_designation': 'Designer', 'employee_skills': ['communication', 'java', 'python', 'data analysis'], 'employee_experience': [{'company_id': 3, 'designation': 'Clinical research associate', 'salary': 33420, 'skills': 'data analysis, python'}]}
# {'employee_id': 993, 'employee_name': 'Patricia Zimmerman', 'employee_salary': 187915, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'communication'], 'employee_experience': [{'company_id': 6, 'designation': 'Architect', 'salary': 35209, 'skills': 'SQL'}]}
# {'employee_id': 994, 'employee_name': 'Lisa Alexander', 'employee_salary': 111595, 'employee_designation': 'Analyst', 'employee_skills': ['SQL', 'python', 'java', 'communication'], 'employee_experience': [{'company_id': 10, 'designation': 'Social researcher', 'salary': 117656, 'skills': 'communication, SQL'}]}
# {'employee_id': 995, 'employee_name': 'Nancy King', 'employee_salary': 82404, 'employee_designation': 'Developer', 'employee_skills': ['data analysis', 'java', 'python', 'communication', 'machine learning'], 'employee_experience': [{'company_id': 4, 'designation': 'Public affairs consultant', 'salary': 42134, 'skills': 'machine learning, data analysis, SQL'}]}
# {'employee_id': 996, 'employee_name': 'Adam Lewis', 'employee_salary': 72043, 'employee_designation': 'Developer', 'employee_skills': ['data analysis'], 'employee_experience': [{'company_id': 4, 'designation': 'Designer, textile', 'salary': 132911, 'skills': 'python, communication'}]}
# {'employee_id': 997, 'employee_name': 'Linda Buchanan', 'employee_salary': 52296, 'employee_designation': 'Designer', 'employee_skills': ['data analysis', 'python', 'SQL', 'machine learning'], 'employee_experience': [{'company_id': 3, 'designation': 'Logistics and distribution manager', 'salary': 45693, 'skills': 'machine learning'}]}
# {'employee_id': 998, 'employee_name': 'Michelle Cook', 'employee_salary': 115613, 'employee_designation': 'Developer', 'employee_skills': ['python'], 'employee_experience': [{'company_id': 1, 'designation': 'Tree surgeon', 'salary': 67490, 'skills': 'SQL'}]}
# {'employee_id': 999, 'employee_name': 'Miranda Swanson', 'employee_salary': 98541, 'employee_designation': 'Analyst', 'employee_skills': ['python', 'communication'], 'employee_experience': [{'company_id': 10, 'designation': 'Public affairs consultant', 'salary': 142838, 'skills': 'communication'}]}
# {'employee_id': 1000, 'employee_name': 'Jessica Diaz', 'employee_salary': 134345, 'employee_designation': 'Manager', 'employee_skills': ['java'], 'employee_experience': [{'company_id': 1, 'designation': 'Merchandiser, retail', 'salary': 65238, 'skills': 'communication, SQL'}]}

# %%
attributes ,var
